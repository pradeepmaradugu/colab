# %% [markdown]
# <a href="https://colab.research.google.com/github/pradeepmaradugu/colab/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
ret = [a**2 for a in range(11) if a%2==0]
ret
# Out:
# [0, 4, 16, 36, 64, 100]
